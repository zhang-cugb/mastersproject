# %% [markdown]
# # Contents and geometry of tunnels and boreholes
# This notebook concatenates tunnel data to existing borehole data to
# have a unified dataframe to locate global coordinates for shearzones.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.extend([
    'C:/Users/Haakon/OneDrive/Dokumenter/FORSKNING/mastersproject/src/mastersproject',
    'C:/Users/Haakon/OneDrive/Dokumenter/FORSKNING/mastersproject/src/mastersproject/GTS'
])

# Notebook images
from IPython.display import Image

# %%
import GTS as gts
# from GTS.ISC_data.isc import ISCData
import numpy as np
import pandas as pd

# %%
cls = gts.ISCData()

# %% [markdown]
# # Extract shear-zone -- tunnel intersections --> global coordinates
# The data on shear-zone -- tunnel intersections should be appended to the existing
# borehole -- shear-zone data to compute global coordinates.

# %%
tn = cls.tunnel_shearzone_data()
tn.head()
# Out:
#             x           y         z  true_dip_direction    dip tunnel  \
# 0  667472.625  158925.321  1733.436              330.00  83.25     AU
# 1  667409.735  158888.360  1735.419              140.90  51.39     VE
# 2  667474.565  158935.311  1733.858              142.25  78.88     AU
# 3  667410.917  158895.617  1734.431              146.44  80.64     VE
# 4  667474.839  158943.317  1733.611              135.33  72.02     AU
#
#    shearzone
# 0         11
# 1         11
# 2         12
# 3         12
# 4         13

# %% [markdown]
# #### Rename shear-zone for clarity

# %%
def rename_sz(sz):
    """ Rename shearzone on form '12' to 'S1_2'. """
    sz = str(sz)
    sz_set = sz[0]
    num = sz[1]
    return f'S{sz_set}_{num}'

# %%
tn['shearzone'] = tn['shearzone'].apply(rename_sz)

# %%
strc = cls.borehole_structure_data().merge(cls.borehole_data(), 
                                                 how='outer', 
                                                 on='borehole',
                                                 suffixes=('_struc', '_bh'), 
                                                 validate='m:1')
strc.head()
# Out:
#    depth  azimuth_struc    dip  aperture                      type borehole  \
# 0   2.35         169.30  57.47    334.61  Minor ductile Shear-zone     FBS1
# 1   2.99         162.65  58.83     35.70  Minor ductile Shear-zone     FBS1
# 2   3.27         172.09  58.07      0.00                 Foliation     FBS1
# 3   5.02         163.86  61.26    578.25  Minor ductile Shear-zone     FBS1
# 4   6.76         169.90  66.49      0.00                 Foliation     FBS1
#
#             x           y         z  length  diameter  azimuth_bh  \
# 0  667466.424  158888.882  1732.782    44.8       101      317.05
# 1  667466.424  158888.882  1732.782    44.8       101      317.05
# 2  667466.424  158888.882  1732.782    44.8       101      317.05
# 3  667466.424  158888.882  1732.782    44.8       101      317.05
# 4  667466.424  158888.882  1732.782    44.8       101      317.05
#
#    upward_gradient
# 0           -31.92
# 1           -31.92
# 2           -31.92
# 3           -31.92
# 4           -31.92

# %% [markdown]
# ### Concatenate shear-zone -- tunnel & shear-zone -- borehole data to one another
# The missing columns for the sz-tunnel data should be filled with 0's. \
# Then, apply the `bh_struc_to_global_coords` method. \
#
# Note: This method will actually do nothing to the sz-tunnel data, because of all 0's.
# Essentially, only GTS-localized coordinates are computed. Other values remain the same / are set to 0.

# %%
strc.columns
# Out:
# Index(['depth', 'azimuth_struc', 'dip', 'aperture', 'type', 'borehole', 'x',
#        'y', 'z', 'length', 'diameter', 'azimuth_bh', 'upward_gradient'],
#       dtype='object')

# %%
{s: 0 for s in strc}
# Out:
# {'depth': 0,
#  'azimuth_struc': 0,
#  'dip': 0,
#  'aperture': 0,
#  'type': 0,
#  'borehole': 0,
#  'x': 0,
#  'y': 0,
#  'z': 0,
#  'length': 0,
#  'diameter': 0,
#  'azimuth_bh': 0,
#  'upward_gradient': 0}

# %%
df = pd.concat([
    strc,
    tn.rename(columns={'true_dip_direction': 'azimuth_struc', 
                       'tunnel': 'borehole', 
#                        'shearzone': 'type',
                      })
],
ignore_index=True,
sort=False).fillna(value={
    **{s: 0 for s in strc},  # All columns in strc: np.NaN --> 0    
})
df.tail(13).head(6)
# Out:
#      depth  azimuth_struc    dip  aperture      type borehole           x  \
# 588  36.31         168.60  64.36       0.0  Fracture     GEO4  667470.776
# 589  38.32         160.06  74.77       0.0  Fracture     GEO4  667470.776
# 590  39.05         180.71  64.95       0.0  Fracture     GEO4  667470.776
# 591   0.00         330.00  83.25       0.0         0       AU  667472.625
# 592   0.00         140.90  51.39       0.0         0       VE  667409.735
# 593   0.00         142.25  78.88       0.0         0       AU  667474.565
#
#               y         z  length  diameter  azimuth_bh  upward_gradient  \
# 588  158912.000  1732.618   40.05      86.0      270.03           -34.22
# 589  158912.000  1732.618   40.05      86.0      270.03           -34.22
# 590  158912.000  1732.618   40.05      86.0      270.03           -34.22
# 591  158925.321  1733.436    0.00       0.0        0.00             0.00
# 592  158888.360  1735.419    0.00       0.0        0.00             0.00
# 593  158935.311  1733.858    0.00       0.0        0.00             0.00
#
#     shearzone
# 588       NaN
# 589       NaN
# 590       NaN
# 591      S1_1
# 592      S1_1
# 593      S1_2

# %%
mapping = {'x': 'x', 'y': 'y', 'z': 'z', 'depth': 'depth', 
           'upward_gradient': 'upward_gradient', 'azimuth': 'azimuth_bh'}
cls.bh_struc_to_global_coords(df, **mapping)
df.tail(13).head(6)
# Out:
#      depth  azimuth_struc    dip  aperture      type borehole           x  \
# 588  36.31         168.60  64.36       0.0  Fracture     GEO4  667470.776
# 589  38.32         160.06  74.77       0.0  Fracture     GEO4  667470.776
# 590  39.05         180.71  64.95       0.0  Fracture     GEO4  667470.776
# 591   0.00         330.00  83.25       0.0         0       AU  667472.625
# 592   0.00         140.90  51.39       0.0         0       VE  667409.735
# 593   0.00         142.25  78.88       0.0         0       AU  667474.565
#
#               y         z  length  ...  shearzone   _trig_x   _trig_y  \
# 588  158912.000  1732.618   40.05  ...        NaN -0.826884  0.000433
# 589  158912.000  1732.618   40.05  ...        NaN -0.826884  0.000433
# 590  158912.000  1732.618   40.05  ...        NaN -0.826884  0.000433
# 591  158925.321  1733.436    0.00  ...       S1_1  0.000000  1.000000
# 592  158888.360  1735.419    0.00  ...       S1_1  0.000000  1.000000
# 593  158935.311  1733.858    0.00  ...       S1_2  0.000000  1.000000
#
#       _trig_z        x_swiss        y_swiss      z_swiss      x_gts  \
# 588 -0.562372  667440.751834  158912.015721  1712.198271  40.751834
# 589 -0.562372  667439.089797  158912.016591  1711.067903  39.089797
# 590 -0.562372  667438.486172  158912.016907  1710.657371  38.486172
# 591  0.000000  667472.625000  158925.321000  1733.436000  72.625000
# 592  0.000000  667409.735000  158888.360000  1735.419000   9.735000
# 593  0.000000  667474.565000  158935.311000  1733.858000  74.565000
#
#           y_gts      z_gts
# 588  112.015721  12.198271
# 589  112.016591  11.067903
# 590  112.016907  10.657371
# 591  125.321000  33.436000
# 592   88.360000  35.419000
# 593  135.311000  33.858000
#
# [6 rows x 23 columns]

# %% [markdown]
# ## Generate DataFrame for all shear-zone usable shearzone measurement points
# The dataset on borehole -- shear-zone intersections only contain information on shear-zone sets, not individual shear-zones. However, there exists more shear-zone measurements than interpolated shear-zones. \
# In other words, some shear-zones are located multiple times along the same borehole.
#
# The ISC visualization tool only uses certain intersections for their interpolation. \
# The datasets in `06_ShearzoneInterpolations > Sx_y.txt` maps 1 shearzone to at most 1 borehole (sometimes no intersection). \
# We will use the same intersections in our analysis - thus disregarding the rest.
#
# ### Flag rows of master df that match in `borehole` and `depth` with `shearzone_borehole_data`

# %%
sz_bh = cls.shearzone_borehole_data()
sz_bh.head()
# Out:
#   borehole  depth shearzone
# 0     INJ1  34.92      S1_1
# 1     INJ2  30.99      S1_1
# 2     FBS1  31.09      S1_1
# 3     FBS2    NaN      S1_1
# 4     FBS3  19.42      S1_1

# %%
sz_bh = sz_bh[sz_bh['depth'].notna()]
sz_bh.head()
# Out:
#   borehole  depth shearzone
# 0     INJ1  34.92      S1_1
# 1     INJ2  30.99      S1_1
# 2     FBS1  31.09      S1_1
# 4     FBS3  19.42      S1_1
# 5     PRP1  33.04      S1_1

# %%
strc.head(2)
# Out:
#    depth  azimuth_struc    dip  aperture                      type borehole  \
# 0   2.35         169.30  57.47    334.61  Minor ductile Shear-zone     FBS1
# 1   2.99         162.65  58.83     35.70  Minor ductile Shear-zone     FBS1
#
#             x           y         z  length  diameter  azimuth_bh  \
# 0  667466.424  158888.882  1732.782    44.8       101      317.05
# 1  667466.424  158888.882  1732.782    44.8       101      317.05
#
#    upward_gradient
# 0           -31.92
# 1           -31.92

# %%
strc_mrg = strc.merge(sz_bh, how='outer', on=['borehole', 'depth'], validate='m:1')
sz = strc_mrg[strc_mrg.shearzone.notna()]
sz
# Out:
#      depth  azimuth_struc    dip  aperture                      type borehole  \
# 18   23.34         140.51  26.14    235.14             S3 Shear-zone     FBS1
# 29   27.83         175.64  38.55    298.08             S3 Shear-zone     FBS1
# 42   31.09         168.02  75.22    847.39             S1 Shear-zone     FBS1
# 50   36.05         170.44  53.09   1228.13             S1 Shear-zone     FBS1
# 62   42.44         164.13  74.91   1513.55             S1 Shear-zone     FBS1
# 105  19.42         157.49  74.12     40.90             S1 Shear-zone     FBS3
# 114  33.39         185.09  70.30     92.00             S3 Shear-zone     FBS3
# 137  42.05         176.65  86.84    179.31             S3 Shear-zone     FBS3
# 173  20.37         183.35  70.51    157.31             S3 Shear-zone     SBH4
# 199  23.79         172.63  74.40    112.98             S3 Shear-zone     SBH4
# 223  28.20         185.40  74.76    132.38             S3 Shear-zone     INJ1
# 227  32.16         185.58  71.04    129.48             S3 Shear-zone     INJ1
# 232  34.92         168.58  67.50    385.90             S1 Shear-zone     INJ1
# 233  34.92         168.33  79.41      4.78                  Fracture     INJ1
# 237  39.11         176.16  68.35   1026.86             S1 Shear-zone     INJ1
# 243  43.20         159.07  88.79    818.47             S1 Shear-zone     INJ1
# 244  43.20         162.51  83.13      0.00                  Fracture     INJ1
# 270  20.29         181.80  76.41    112.05             S3 Shear-zone     INJ2
# 281  26.68         178.56  72.68    116.04             S3 Shear-zone     INJ2
# 291  30.99         159.42  82.73   1549.05             S1 Shear-zone     INJ2
# 299  34.35         141.69  81.59    755.82             S1 Shear-zone     INJ2
# 302  38.68         168.96  70.83   3120.51             S1 Shear-zone     INJ2
# 324  23.71         176.66  79.33    160.75             S3 Shear-zone     PRP1
# 339  29.31         174.71  78.67    138.99             S3 Shear-zone     PRP1
# 343  33.04         160.05  87.61   1282.34             S1 Shear-zone     PRP1
# 357  43.04         342.99  89.01   1082.66             S1 Shear-zone     PRP1
# 367  46.34         141.59  86.37   1884.28             S1 Shear-zone     PRP1
# 404  22.17         180.49  75.09    157.28             S3 Shear-zone     PRP2
# 417  27.43         187.34  69.30     70.91             S3 Shear-zone     PRP2
# 420  30.10         343.86  82.39    887.75             S1 Shear-zone     PRP2
# 426  34.43         190.78  63.71   1162.53             S1 Shear-zone     PRP2
# 440  41.85         154.67  80.82   1831.76             S1 Shear-zone     PRP2
# 465  15.57         185.46  60.58    308.85             S3 Shear-zone     PRP3
# 473  19.34         166.63  56.55    315.75             S3 Shear-zone     PRP3
# 486  31.14         166.40  54.90   1201.46             S1 Shear-zone     PRP3
# 530  18.63         165.74  74.19   1244.19             S1 Shear-zone     GEO3
# 544  26.49         165.79  73.15    380.94  Minor ductile Shear-zone     GEO3
# 568  19.52         150.11  70.51   1463.44             S1 Shear-zone     GEO4
# 578  28.05         159.34  58.95    437.50             S1 Shear-zone     GEO4
# 585  35.62         163.76  68.19    635.98             S1 Shear-zone     GEO4
# 591  25.58            NaN    NaN       NaN                       NaN     PRP3
#
#               x           y         z  length  diameter  azimuth_bh  \
# 18   667466.424  158888.882  1732.782   44.80     101.0      317.05
# 29   667466.424  158888.882  1732.782   44.80     101.0      317.05
# 42   667466.424  158888.882  1732.782   44.80     101.0      317.05
# 50   667466.424  158888.882  1732.782   44.80     101.0      317.05
# 62   667466.424  158888.882  1732.782   44.80     101.0      317.05
# 105  667471.317  158926.213  1732.263   44.00     101.0      219.92
# 114  667471.317  158926.213  1732.263   44.00     101.0      219.92
# 137  667471.317  158926.213  1732.263   44.00     101.0      219.92
# 173  667468.729  158892.774  1733.910   23.90     101.0      320.00
# 199  667468.729  158892.774  1733.910   23.90     101.0      320.00
# 223  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 227  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 232  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 233  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 237  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 243  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 244  667466.231  158888.399  1732.817   44.66     146.0      309.57
# 270  667466.787  158890.217  1732.881   44.80     146.0      332.28
# 281  667466.787  158890.217  1732.881   44.80     146.0      332.28
# 291  667466.787  158890.217  1732.881   44.80     146.0      332.28
# 299  667466.787  158890.217  1732.881   44.80     146.0      332.28
# 302  667466.787  158890.217  1732.881   44.80     146.0      332.28
# 324  667466.510  158889.310  1732.640   47.91     131.0      320.00
# 339  667466.510  158889.310  1732.640   47.91     131.0      320.00
# 343  667466.510  158889.310  1732.640   47.91     131.0      320.00
# 357  667466.510  158889.310  1732.640   47.91     131.0      320.00
# 367  667466.510  158889.310  1732.640   47.91     131.0      320.00
# 404  667466.510  158889.310  1733.120   44.98     131.0      321.99
# 417  667466.510  158889.310  1733.120   44.98     131.0      321.99
# 420  667466.510  158889.310  1733.120   44.98     131.0      321.99
# 426  667466.510  158889.310  1733.120   44.98     131.0      321.99
# 440  667466.510  158889.310  1733.120   44.98     131.0      321.99
# 465  667468.390  158892.660  1733.100   32.33     131.0      335.01
# 473  667468.390  158892.660  1733.100   32.33     131.0      335.01
# 486  667468.390  158892.660  1733.100   32.33     131.0      335.01
# 530  667470.923  158912.008  1732.416   30.10      86.0      269.96
# 544  667470.923  158912.008  1732.416   30.10      86.0      269.96
# 568  667470.776  158912.000  1732.618   40.05      86.0      270.03
# 578  667470.776  158912.000  1732.618   40.05      86.0      270.03
# 585  667470.776  158912.000  1732.618   40.05      86.0      270.03
# 591         NaN         NaN       NaN     NaN       NaN         NaN
#
#      upward_gradient shearzone
# 18            -31.92      S3_1
# 29            -31.92      S3_2
# 42            -31.92      S1_1
# 50            -31.92      S1_2
# 62            -31.92      S1_3
# 105           -37.33      S1_1
# 114           -37.33      S3_2
# 137           -37.33      S3_1
# 173             5.00      S3_1
# 199             5.00      S3_2
# 223           -33.52      S3_1
# 227           -33.52      S3_2
# 232           -33.52      S1_1
# 233           -33.52      S1_1
# 237           -33.52      S1_2
# 243           -33.52      S1_3
# 244           -33.52      S1_3
# 270           -43.65      S3_1
# 281           -43.65      S3_2
# 291           -43.65      S1_1
# 299           -43.65      S1_2
# 302           -43.65      S1_3
# 324           -44.00      S3_1
# 339           -44.00      S3_2
# 343           -44.00      S1_1
# 357           -44.00      S1_2
# 367           -44.00      S1_3
# 404           -31.99      S3_1
# 417           -31.99      S3_2
# 420           -31.99      S1_1
# 426           -31.99      S1_2
# 440           -31.99      S1_3
# 465           -25.00      S3_1
# 473           -25.00      S3_2
# 486           -25.00      S1_2
# 530           -47.80      S1_1
# 544           -47.80      S1_2
# 568           -34.22      S1_1
# 578           -34.22      S1_2
# 585           -34.22      S1_3
# 591              NaN      S1_1

# %% [markdown]
# ## Issue: One value is not matched up...

# %%
sz[sz.type.isna()]
# Out:
#      depth  azimuth_struc  dip  aperture type borehole   x   y   z  length  \
# 591  25.58            NaN  NaN       NaN  NaN     PRP3 NaN NaN NaN     NaN
#
#      diameter  azimuth_bh  upward_gradient shearzone
# 591       NaN         NaN              NaN      S1_1

# %%
sz_bh[sz_bh.borehole == 'PRP3']
# Out:
#    borehole  depth shearzone
# 7      PRP3  25.58      S1_1
# 22     PRP3  31.14      S1_2
# 52     PRP3  15.57      S3_1
# 67     PRP3  19.34      S3_2

# %%
t0 = cls.borehole_shearzone_data()
t0[(t0.borehole == 'PRP3') & (t0.type.isin(['S1 Shear-zone']))]
# Out:
#      depth  azimuth    dip  aperture           type borehole
# 478  21.18    178.1  72.90   1612.92  S1 Shear-zone     PRP3
# 483  25.57    176.5  55.72   1539.04  S1 Shear-zone     PRP3
# 486  31.14    166.4  54.90   1201.46  S1 Shear-zone     PRP3

# %% [markdown]
# ### Explanation for why it isn't matched
# As we can see, $25.58 \neq 25.57$, so the match is not found. \
# We solve this by merging with `pd.merge_asof`: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.merge_asof.html.

# %%
t = pd.merge_asof(strc.sort_values('depth'),
                  sz_bh.sort_values('depth'),
                  by='borehole', 
                  on='depth',
                  tolerance=0.01, 
                  direction='nearest')
tt = t[t.shearzone.notna()]
t3 = tt[tt['borehole'] == 'PRP3']

# %%
tt = tt[tt.type.isin(['S1 Shear-zone', 'S3 Shear-zone', 'Minor ductile Shear-zone'])]
tt[tt['borehole'] == 'PRP3']
# Out:
#      depth  azimuth_struc    dip  aperture           type borehole          x  \
# 151  15.57         185.46  60.58    308.85  S3 Shear-zone     PRP3  667468.39
# 216  19.34         166.63  56.55    315.75  S3 Shear-zone     PRP3  667468.39
# 336  25.57         176.50  55.72   1539.04  S1 Shear-zone     PRP3  667468.39
# 415  31.14         166.40  54.90   1201.46  S1 Shear-zone     PRP3  667468.39
#
#              y       z  length  diameter  azimuth_bh  upward_gradient  \
# 151  158892.66  1733.1   32.33       131      335.01            -25.0
# 216  158892.66  1733.1   32.33       131      335.01            -25.0
# 336  158892.66  1733.1   32.33       131      335.01            -25.0
# 415  158892.66  1733.1   32.33       131      335.01            -25.0
#
#     shearzone
# 151      S3_1
# 216      S3_2
# 336      S1_1
# 415      S1_2

# %%
tt.shape
# Out:
# (39, 14)

# %%
sz[sz['borehole']=='PRP3']
# Out:
#      depth  azimuth_struc    dip  aperture           type borehole          x  \
# 465  15.57         185.46  60.58    308.85  S3 Shear-zone     PRP3  667468.39
# 473  19.34         166.63  56.55    315.75  S3 Shear-zone     PRP3  667468.39
# 486  31.14         166.40  54.90   1201.46  S1 Shear-zone     PRP3  667468.39
# 591  25.58            NaN    NaN       NaN            NaN     PRP3        NaN
#
#              y       z  length  diameter  azimuth_bh  upward_gradient  \
# 465  158892.66  1733.1   32.33     131.0      335.01            -25.0
# 473  158892.66  1733.1   32.33     131.0      335.01            -25.0
# 486  158892.66  1733.1   32.33     131.0      335.01            -25.0
# 591        NaN     NaN     NaN       NaN         NaN              NaN
#
#     shearzone
# 465      S3_1
# 473      S3_2
# 486      S1_2
# 591      S1_1

# %%
sz.shape
# Out:
# (41, 14)

# %% [markdown]
# ### _Issue:_ `merge_asof` brings along something of `type = fracture`
# See index 152 of `tt[tt['borehole'] == 'PRP3']`.

# %% [markdown]
# ## Add type to shear-zone -- borehole data
# Then, merge on both `borehole` and `type` to ensure that no fractures are counted.

# %%
# Import shear-zone -- borehole data.
sz_bh = cls.shearzone_borehole_data()
sz_bh = sz_bh[sz_bh['depth'].notna()]  # Remove NaN's.

# Add column representing shear-zone set.
sz_bh['type'] = sz_bh['shearzone'].str[:2] + ' Shear-zone'
sz_bh.head(3)
# Out:
#   borehole  depth shearzone           type
# 0     INJ1  34.92      S1_1  S1 Shear-zone
# 1     INJ2  30.99      S1_1  S1 Shear-zone
# 2     FBS1  31.09      S1_1  S1 Shear-zone

# %%
strc = cls.borehole_structure_data().merge(cls.borehole_data(), 
                                                 how='outer', 
                                                 on='borehole',
                                                 suffixes=('_struc', '_bh'), 
                                                 validate='m:1')
strc.head(3)
# Out:
#    depth  azimuth_struc    dip  aperture                      type borehole  \
# 0   2.35         169.30  57.47    334.61  Minor ductile Shear-zone     FBS1
# 1   2.99         162.65  58.83     35.70  Minor ductile Shear-zone     FBS1
# 2   3.27         172.09  58.07      0.00                 Foliation     FBS1
#
#             x           y         z  length  diameter  azimuth_bh  \
# 0  667466.424  158888.882  1732.782    44.8       101      317.05
# 1  667466.424  158888.882  1732.782    44.8       101      317.05
# 2  667466.424  158888.882  1732.782    44.8       101      317.05
#
#    upward_gradient
# 0           -31.92
# 1           -31.92
# 2           -31.92

# %%
merged = pd.merge_asof(strc.sort_values('depth'),
                  sz_bh.sort_values('depth'),
                  by=['borehole', 'type'], 
                  on='depth',
                  tolerance=0.01, 
                  direction='nearest')
merged.head(2)
# Out:
#    depth  azimuth_struc    dip  aperture      type borehole           x  \
# 0   1.76         239.29  86.44      1.89  Fracture     SBH3  667468.567
# 1   2.11          78.11  21.13      0.00  Fracture     PRP3  667468.390
#
#             y        z  length  diameter  azimuth_bh  upward_gradient  \
# 0  158885.383  1733.96   20.55       101      190.07             4.91
# 1  158892.660  1733.10   32.33       131      335.01           -25.00
#
#   shearzone
# 0       NaN
# 1       NaN

# %%
test_type='INJ1'

# %%
merged[merged.shearzone.notna()]['borehole'].value_counts().sort_index()
# Out:
# FBS1    5
# FBS3    3
# GEO3    1
# GEO4    3
# INJ1    5
# INJ2    5
# PRP1    5
# PRP2    5
# PRP3    4
# SBH4    2
# Name: borehole, dtype: int64

# %%
sz_bh['borehole'].value_counts().sort_index()
# Out:
# FBS1    5
# FBS3    3
# GEO3    2
# GEO4    3
# INJ1    5
# INJ2    5
# PRP1    5
# PRP2    5
# PRP3    4
# SBH4    2
# Name: borehole, dtype: int64

# %% [markdown]
# Notice the discreprancy in `GEO3`, above.

# %%
merged[(merged.shearzone.notna()) & (merged.borehole=='GEO3')]
# Out:
#      depth  azimuth_struc    dip  aperture           type borehole  \
# 199  18.63         165.74  74.19   1244.19  S1 Shear-zone     GEO3
#
#               x           y         z  length  diameter  azimuth_bh  \
# 199  667470.923  158912.008  1732.416    30.1        86      269.96
#
#      upward_gradient shearzone
# 199            -47.8      S1_1

# %%
sz_bh[sz_bh.borehole=='GEO3']
# Out:
#    borehole  depth shearzone           type
# 10     GEO3  18.63      S1_1  S1 Shear-zone
# 25     GEO3  26.49      S1_2  S1 Shear-zone

# %%
strc[(strc.borehole=='GEO3')].tail()
# Out:
#      depth  azimuth_struc    dip  aperture                      type borehole  \
# 542  25.32         150.68  85.56      0.00                  Fracture     GEO3
# 543  25.37         159.50  78.99      0.00                  Fracture     GEO3
# 544  26.49         165.79  73.15    380.94  Minor ductile Shear-zone     GEO3
# 545  26.73         160.03  82.12      0.00                  Fracture     GEO3
# 546  27.66         161.16  66.69      0.00                  Fracture     GEO3
#
#               x           y         z  length  diameter  azimuth_bh  \
# 542  667470.923  158912.008  1732.416    30.1        86      269.96
# 543  667470.923  158912.008  1732.416    30.1        86      269.96
# 544  667470.923  158912.008  1732.416    30.1        86      269.96
# 545  667470.923  158912.008  1732.416    30.1        86      269.96
# 546  667470.923  158912.008  1732.416    30.1        86      269.96
#
#      upward_gradient
# 542            -47.8
# 543            -47.8
# 544            -47.8
# 545            -47.8
# 546            -47.8

# %% [markdown]
# Notice, above, we were missing something on depth $26.49$. This is exactly the structure classified as a `Minor ductile Shear-zone`
#
# ## This method, above, fails under the assumption that all shear zones are either `S1 Shear-zone` or `S3 Shear-zone`

# %% [markdown]
# --------------------
# # Next attempt

# %%
# Import shear-zone -- borehole data.
sz_bh = cls.shearzone_borehole_data()
sz_bh = sz_bh[sz_bh['depth'].notna()]  # Remove rows with no intersection.
sz_bh
# Out:
#    borehole  depth shearzone
# 0      INJ1  34.92      S1_1
# 1      INJ2  30.99      S1_1
# 2      FBS1  31.09      S1_1
# 4      FBS3  19.42      S1_1
# 5      PRP1  33.04      S1_1
# 6      PRP2  30.10      S1_1
# 7      PRP3  25.58      S1_1
# 10     GEO3  18.63      S1_1
# 11     GEO4  19.52      S1_1
# 15     INJ1  39.11      S1_2
# 16     INJ2  34.35      S1_2
# 17     FBS1  36.05      S1_2
# 20     PRP1  43.04      S1_2
# 21     PRP2  34.43      S1_2
# 22     PRP3  31.14      S1_2
# 25     GEO3  26.49      S1_2
# 26     GEO4  28.05      S1_2
# 30     INJ1  43.20      S1_3
# 31     INJ2  38.68      S1_3
# 32     FBS1  42.44      S1_3
# 35     PRP1  46.34      S1_3
# 36     PRP2  41.85      S1_3
# 41     GEO4  35.62      S1_3
# 45     INJ1  28.20      S3_1
# 46     INJ2  20.29      S3_1
# 47     FBS1  23.34      S3_1
# 49     FBS3  42.05      S3_1
# 50     PRP1  23.71      S3_1
# 51     PRP2  22.17      S3_1
# 52     PRP3  15.57      S3_1
# 59     SBH4  20.37      S3_1
# 60     INJ1  32.16      S3_2
# 61     INJ2  26.68      S3_2
# 62     FBS1  27.83      S3_2
# 64     FBS3  33.39      S3_2
# 65     PRP1  29.31      S3_2
# 66     PRP2  27.43      S3_2
# 67     PRP3  19.34      S3_2
# 74     SBH4  23.79      S3_2

# %%
strc = cls.borehole_structure_data().merge(cls.borehole_data(), how='outer', on='borehole', 
                                           suffixes=('_struc', '_bh'), validate='m:1')
strc['shearzone'] = np.nan
strc1 = strc.loc[:,['depth', 'type', 'borehole', 'shearzone']]
strc1.head()
# Out:
#    depth                      type borehole  shearzone
# 0   2.35  Minor ductile Shear-zone     FBS1        NaN
# 1   2.99  Minor ductile Shear-zone     FBS1        NaN
# 2   3.27                 Foliation     FBS1        NaN
# 3   5.02  Minor ductile Shear-zone     FBS1        NaN
# 4   6.76                 Foliation     FBS1        NaN

# %%
# This mask filters potential shear-zones with other structures.
_mask_sz = strc.loc[:,'type'].isin(['Minor ductile Shear-zone', 'S1 Shear-zone', 'S3 Shear-zone']).values

# %%
strc.loc[_mask_sz, '']
# Out:
# Index(['depth', 'azimuth_struc', 'dip', 'aperture', 'type', 'borehole', 'x',
#        'y', 'z', 'length', 'diameter', 'azimuth_bh', 'upward_gradient',
#        'shearzone'],
#       dtype='object')

# %% [markdown]
# #### Next:
# Merge the `structure` data with the `shearzone-borehole` data. \
# Note that we have drastically increased the number of rows. This is because merge solely based on matching borehole. \
# Therefore, we need to remove to superfluous data before proceeding.

# %%
# Merge borehole-structures with shearzone-boreholes.
strc_mrg = strc.merge(sz_bh, how='outer', on=['borehole', 'depth'])

sz = strc_mrg[strc_mrg.shearzone.notna()]  # I don't quite understand/remember why this filter is here.
sz.type.value_counts(dropna=False)
# Out:
# S1 Shear-zone               21
# S3 Shear-zone               16
# Fracture                     2
# Minor ductile Shear-zone     1
# NaN                          1
# Name: type, dtype: int64

# %%
strc_mrg.type.value_counts(dropna=False)
# Out:
# Fracture                    412
# Quartz                       67
# S1 Shear-zone                34
# Foliation                    29
# S3 Shear-zone                28
# Minor ductile Shear-zone     15
# Biotite Band                  6
# NaN                           1
# Name: type, dtype: int64

# %%
sz.head(3)
# Out:
#    depth_x  azimuth_struc    dip  aperture                      type borehole  \
# 0     2.35          169.3  57.47    334.61  Minor ductile Shear-zone     FBS1
# 1     2.35          169.3  57.47    334.61  Minor ductile Shear-zone     FBS1
# 2     2.35          169.3  57.47    334.61  Minor ductile Shear-zone     FBS1
#
#             x           y         z  length  diameter  azimuth_bh  \
# 0  667466.424  158888.882  1732.782    44.8       101      317.05
# 1  667466.424  158888.882  1732.782    44.8       101      317.05
# 2  667466.424  158888.882  1732.782    44.8       101      317.05
#
#    upward_gradient  depth_y shearzone
# 0           -31.92    31.09      S1_1
# 1           -31.92    36.05      S1_2
# 2           -31.92    42.44      S1_3

# %%
_mask = np.isclose(sz.depth_x.values, sz.depth_y.values, atol=0.01)
_mask2 = sz.type.isin(['Minor ductile Shear-zone', 'S1 Shear-zone', 'S3 Shear-zone'])
sz2 = sz[_mask]

# %%
sz2.shape
# Out:
# (42, 15)

# %%
sz[_mask & _mask2].shape
# Out:
# (39, 15)

# %% [markdown]
# #### This `_mask` finds the shear zones used for computer simulations
# We expect 39 locations for "real" shear-zones.

# %%
_mask = (np.isclose(sz.depth_x.values, sz.depth_y.values, atol=0.01) & 
        (sz.type.isin(['Minor ductile Shear-zone', 'S1 Shear-zone', 'S3 Shear-zone'])))

_mask.value_counts()
# Out:
# False    2097
# True       39
# Name: type, dtype: int64

# %%
sz.loc[~_mask.values, 'shearzone'] = np.nan

sz.shearzone.value_counts(dropna=False)
# Out:
# NaN     2097
# S1_1       9
# S3_2       8
# S1_2       8
# S3_1       8
# S1_3       6
# Name: shearzone, dtype: int64

# %%
sz
# Out:
#       depth_x  azimuth_struc    dip  aperture                      type  \
# 0        2.35         169.30  57.47    334.61  Minor ductile Shear-zone
# 1        2.35         169.30  57.47    334.61  Minor ductile Shear-zone
# 2        2.35         169.30  57.47    334.61  Minor ductile Shear-zone
# 3        2.35         169.30  57.47    334.61  Minor ductile Shear-zone
# 4        2.35         169.30  57.47    334.61  Minor ductile Shear-zone
# ...       ...            ...    ...       ...                       ...
# 2210    38.32         160.06  74.77      0.00                  Fracture
# 2211    38.32         160.06  74.77      0.00                  Fracture
# 2212    39.05         180.71  64.95      0.00                  Fracture
# 2213    39.05         180.71  64.95      0.00                  Fracture
# 2214    39.05         180.71  64.95      0.00                  Fracture
#
#      borehole           x           y         z  length  diameter  azimuth_bh  \
# 0        FBS1  667466.424  158888.882  1732.782   44.80       101      317.05
# 1        FBS1  667466.424  158888.882  1732.782   44.80       101      317.05
# 2        FBS1  667466.424  158888.882  1732.782   44.80       101      317.05
# 3        FBS1  667466.424  158888.882  1732.782   44.80       101      317.05
# 4        FBS1  667466.424  158888.882  1732.782   44.80       101      317.05
# ...       ...         ...         ...       ...     ...       ...         ...
# 2210     GEO4  667470.776  158912.000  1732.618   40.05        86      270.03
# 2211     GEO4  667470.776  158912.000  1732.618   40.05        86      270.03
# 2212     GEO4  667470.776  158912.000  1732.618   40.05        86      270.03
# 2213     GEO4  667470.776  158912.000  1732.618   40.05        86      270.03
# 2214     GEO4  667470.776  158912.000  1732.618   40.05        86      270.03
#
#       upward_gradient  depth_y shearzone
# 0              -31.92    31.09       NaN
# 1              -31.92    36.05       NaN
# 2              -31.92    42.44       NaN
# 3              -31.92    23.34       NaN
# 4              -31.92    27.83       NaN
# ...               ...      ...       ...
# 2210           -34.22    28.05       NaN
# 2211           -34.22    35.62       NaN
# 2212           -34.22    19.52       NaN
# 2213           -34.22    28.05       NaN
# 2214           -34.22    35.62       NaN
#
# [2136 rows x 15 columns]

# %% [markdown]
# # IntervalIndex
# See: https://stackoverflow.com/a/46772977

# %%
# Import shear-zone -- borehole data.
sz_bh = cls.shearzone_borehole_data()
df1 = sz_bh[sz_bh['depth'].notna()]  # Remove rows with no intersection.
df1.head()
# Out:
#   borehole  depth shearzone
# 0     INJ1  34.92      S1_1
# 1     INJ2  30.99      S1_1
# 2     FBS1  31.09      S1_1
# 4     FBS3  19.42      S1_1
# 5     PRP1  33.04      S1_1

# %%
strc = cls.borehole_structure_data().merge(cls.borehole_data(), how='outer', on='borehole', 
                                           suffixes=('_struc', '_bh'), validate='m:1')
# strc['shearzone'] = np.nan
df2 = strc.loc[:,('depth', 'type', 'borehole')]
df2.head()
# Out:
#    depth                      type borehole
# 0   2.35  Minor ductile Shear-zone     FBS1
# 1   2.99  Minor ductile Shear-zone     FBS1
# 2   3.27                 Foliation     FBS1
# 3   5.02  Minor ductile Shear-zone     FBS1
# 4   6.76                 Foliation     FBS1

# %%
pd.merge_asof(df2.sort_values('depth'), df1.sort_values('depth'), 
              direction='nearest', 
              on='depth', 
              by='borehole').sort_values('shearzone').drop_duplicates('shearzone')
# Out:
#      depth           type borehole shearzone
# 243  20.65       Fracture     GEO4      S1_1
# 451  34.35  S1 Shear-zone     INJ2      S1_2
# 588  47.36       Fracture     PRP1      S1_3
# 333  25.51       Fracture     PRP1      S3_1
# 290  22.99      Foliation     SBH4      S3_2
# 0     1.76       Fracture     SBH3       NaN

# %%
tol=0.011
df2.index = pd.IntervalIndex.from_arrays(df2['depth']-tol, df2['depth']+tol, closed='both')
df1['shearzone']
# Out:
#                              depth                      type borehole
# [2.339, 2.361]                2.35  Minor ductile Shear-zone     FBS1
# [2.979, 3.0010000000000003]   2.99  Minor ductile Shear-zone     FBS1
# [3.259, 3.281]                3.27                 Foliation     FBS1
# [5.0089999999999995, 5.031]   5.02  Minor ductile Shear-zone     FBS1
# [6.749, 6.771]                6.76                 Foliation     FBS1

# %% [markdown]
# df1 has [A,C] df2 has [A,B]
#
# do tolerance on df2.A to include values from df1.
